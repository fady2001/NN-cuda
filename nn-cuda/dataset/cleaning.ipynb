# %%
import pandas as pd
import numpy as np

def clean_data(file_path):
    """
    Clean and preprocess the data.

    Parameters:
    - file_path (str): Path to the CSV file containing the data.

    Returns:
    - x (pd.DataFrame): Normalized feature data.
    - y (pd.Series): Encoded labels.
    """
    # Load the data
    df = pd.read_csv(file_path)
    
    # shuffle the data 
    df = df.sample(frac=1).reset_index(drop=True)

    
    # Separate the features and the labels
    y = df['label']
    x = df.drop(['label'], axis=1)

    # Normalize the feature data
    x = (x - x.mean()) / x.std()
    print(x.iloc[0])
    # Ordinal encoding for the label
    unique_labels = y.unique()
    label_dict = {unique_labels[i]: i for i in range(len(unique_labels))}
    y = y.map(label_dict)

    return x, y

# Example usage:
train_path = 'train_data_final.csv'
test_path = 'test_data_final.csv'

x_train, y_train = clean_data(train_path)
x_test, y_test = clean_data(test_path)

print(x_train.head())
print(y_train.head())
print(x_test.head())
print(y_test.head())
# save as npy files
x_train = x_train.to_numpy().astype(np.float32, order='C')
y_train = y_train.to_numpy().astype(np.uint, order='C')
x_test = x_test.to_numpy().astype(np.float32, order='C')
y_test = y_test.to_numpy().astype(np.uint, order='C')

np.save('x_train.npy', x_train)
np.save('y_train.npy', y_train)
np.save('x_test.npy', x_test)
np.save('y_test.npy', y_test)
# Out:
# rmse_mean                  1.280204
# rmse_std                   0.193029
# spectral_centroid_mean     0.148130
# spectral_centroid_std     -0.918708
# spectral_bandwidth_mean    0.399287
#                              ...
# tonnetz6_std              -0.690576
# chroma_cqt_mean           -1.533530
# chroma_cqt_std             0.192809
# spectral_contrast_mean    -0.711459
# spectral_contrast_std     -0.227020
# Name: 0, Length: 130, dtype: float64
# rmse_mean                 -0.419098
# rmse_std                  -0.958877
# spectral_centroid_mean     0.788694
# spectral_centroid_std     -0.227098
# spectral_bandwidth_mean    0.920139
#                              ...
# tonnetz6_std              -0.563680
# chroma_cqt_mean            1.908725
# chroma_cqt_std            -1.546972
# spectral_contrast_mean    -1.268329
# spectral_contrast_std      0.198919
# Name: 0, Length: 130, dtype: float64
#    rmse_mean  rmse_std  spectral_centroid_mean  spectral_centroid_std  \
# 0   1.280204  0.193029                0.148130              -0.918708
# 1  -0.692261  3.073387               -1.403619               1.967882
# 2   1.225001 -0.862206                0.426080              -1.466851
# 3   0.129845 -1.712893               -0.033665              -1.603754
# 4  -0.583639  0.363490               -0.379050               2.158621
#
#    spectral_bandwidth_mean  spectral_bandwidth_std  rolloff_mean  rolloff_std  \
# 0                 0.399287               -1.126301      0.337140    -0.898156
# 1                -1.394868                2.671823     -1.491013     2.263363
# 2                 0.650278               -1.340543      0.642889    -1.335493
# 3                 0.193511               -0.809016      0.074869    -0.998738
# 4                -0.240254                1.604616     -0.380849     1.869777
#
#    zero_crossing_rate_mean  zero_crossing_rate_std  ...  tonnetz4_mean  \
# 0                -0.454513                0.062160  ...       0.255284
# 1                -0.964629                0.224453  ...       0.036426
# 2                -0.259977               -0.445287  ...      -0.338514
# 3                -0.256440               -1.170508  ...      -0.152929
# 4                -0.436592                0.791291  ...       0.363472
#
#    tonnetz4_std  tonnetz5_mean  tonnetz5_std  tonnetz6_mean  tonnetz6_std  \
# 0     -0.611671       0.377441     -0.726746      -0.114242     -0.690576
# 1     -0.001352      -1.233992      1.744839       0.228774     -0.115759
# 2      0.274657      -0.291135     -0.499777      -1.019228     -0.095353
# 3     -0.553012       0.280315     -0.812567       0.501956     -0.677519
# 4     -0.364242      -0.117560     -0.671799       0.215275     -0.580066
#
#    chroma_cqt_mean  chroma_cqt_std  spectral_contrast_mean  \
# 0        -1.533530        0.192809               -0.711459
# 1         0.261661        1.587278                0.900272
# 2        -0.955771       -0.325141               -0.695484
# 3         1.077084       -1.797914               -1.193048
# 4         0.378935       -0.458236               -0.289554
#
#    spectral_contrast_std
# 0              -0.227020
# 1              -1.301022
# 2              -0.844307
# 3               0.377291
# 4               0.436985
#
# [5 rows x 130 columns]
# 0    0
# 1    1
# 2    0
# 3    2
# 4    3
# Name: label, dtype: int64
#    rmse_mean  rmse_std  spectral_centroid_mean  spectral_centroid_std  \
# 0  -0.419098 -0.958877                0.788694              -0.227098
# 1  -0.581772  0.520922                0.294116               1.535038
# 2  -0.775653  0.678761               -1.387481              -0.479674
# 3   2.310746 -0.303129               -0.278683               0.234980
# 4   0.721400  0.223276                1.702934              -0.035595
#
#    spectral_bandwidth_mean  spectral_bandwidth_std  rolloff_mean  rolloff_std  \
# 0                 0.920139               -1.138307      0.921102    -1.010488
# 1                 0.460412                0.854541      0.327823     1.151360
# 2                -1.396198                0.085776     -1.430621    -0.069159
# 3                 0.152592                0.325802     -0.152374     0.614707
# 4                 0.869592               -0.838455      1.280853    -0.855909
#
#    zero_crossing_rate_mean  zero_crossing_rate_std  ...  tonnetz4_mean  \
# 0                 0.294255                0.323279  ...      -0.261570
# 1                 0.209914                0.777967  ...       0.454269
# 2                -0.922305               -0.803989  ...      -3.953084
# 3                -0.746023               -0.242908  ...      -0.963757
# 4                 2.118393                1.178093  ...       0.526904
#
#    tonnetz4_std  tonnetz5_mean  tonnetz5_std  tonnetz6_mean  tonnetz6_std  \
# 0     -0.928327      -0.121871     -0.733117       0.273725     -0.563680
# 1      1.422320       0.109829      1.887751      -0.585760      0.626999
# 2      2.104247      -4.280862      1.509510       0.223981      0.644338
# 3      2.045560       2.280034      0.927502      -0.650275      1.320433
# 4      0.146472      -1.159647      0.702176       0.456955      0.197896
#
#    chroma_cqt_mean  chroma_cqt_std  spectral_contrast_mean  \
# 0         1.908725       -1.546972               -1.268329
# 1        -0.821709        0.947470                0.345747
# 2        -0.513510        1.754694                2.057966
# 3        -1.142712        0.761189                0.622736
# 4         0.362806        0.169593               -0.086266
#
#    spectral_contrast_std
# 0               0.198919
# 1               0.389660
# 2              -1.080518
# 3               0.295459
# 4              -0.016272
#
# [5 rows x 130 columns]
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: label, dtype: int64

# %%
# read npy files
x_train = np.load('x_train.npy')
print(x_train.shape)
print(x_train[0])
print(x_train.dtype)
y_train = np.load('y_train.npy')
print(y_train.shape)
print(y_train[0])
print(y_train.dtype)
# Out:
# (32000, 130)
# [ 1.2802037   0.1930291   0.14813042 -0.9187077   0.39928705 -1.1263012
#   0.3371404  -0.8981565  -0.45451304  0.0621605   1.0560607  -1.3348378
#  -0.0733905  -1.044068   -0.19040577 -1.309372   -0.5134216  -0.8083802
#  -0.9226823  -0.82346004 -0.630479   -0.8292406  -0.30959445 -0.6063041
#   0.47326967 -1.1096132   0.93647605 -1.3001195   1.1064268  -0.97503984
#   0.99309564 -0.4860793   0.75378454 -0.3216847   0.3706675  -0.6359648
#   0.44073683 -0.95372987  0.02045424 -1.0794158   0.15339833 -1.1014866
#   0.10339521 -1.010531    0.25264156 -0.9992745   0.01791598 -0.4988723
#   0.47676328 -0.42679846  0.46276245 -0.16447748  0.47393793 -0.5530521
#   0.57042205 -0.43238965  0.198013   -0.4687996  -0.10174983 -0.5659673
#   0.04667875 -0.5686789   0.12115318 -0.81296015  0.39833286 -0.2668084
#   0.5142624  -0.7741534   0.30212298 -0.25643107  0.5739981  -0.5504623
#   0.9862857  -0.1276196   0.9586745  -0.5532855   0.33066446 -0.7535795
#  -0.4247169  -1.0487133  -0.3856089  -1.069695   -0.27382615 -0.47790456
#  -0.12411349 -0.23853706  0.32118928 -0.21791959  0.15869905 -0.7005257
#   0.2759716  -0.19725773 -0.23807651 -1.248589   -0.84960705 -1.384387
#  -0.57556224  0.46672824  0.17792276  1.1188298   0.26198274  0.44864434
#  -0.42049652 -1.2030116  -0.05810964 -0.7015203   0.6622668   0.17826311
#   1.5553112   0.25191063  1.5763041   0.00297388  0.51400244 -0.14968969
#  -0.01851577 -0.8955256   0.301095   -0.62079763 -0.71004975 -0.58484447
#   0.25528362 -0.6116711   0.37744078 -0.72674614 -0.11424235 -0.6905758
#  -1.5335304   0.19280852 -0.7114589  -0.22702026]
# float32
# (32000,)
# 0
# uint32
