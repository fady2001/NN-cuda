# %%
import pandas as pd
import numpy as np

def clean_data(file_path):
    """
    Clean and preprocess the data.

    Parameters:
    - file_path (str): Path to the CSV file containing the data.

    Returns:
    - x (pd.DataFrame): Normalized feature data.
    - y (pd.Series): Encoded labels.
    """
    # Load the data
    df = pd.read_csv(file_path)
    
    # shuffle the data 
    df = df.sample(frac=1).reset_index(drop=True)

    
    # Separate the features and the labels
    y = df['label']
    x = df.drop(['label'], axis=1)

    # Normalize the feature data
    x = (x - x.mean()) / x.std()

    # Ordinal encoding for the label
    unique_labels = y.unique()
    label_dict = {unique_labels[i]: i for i in range(len(unique_labels))}
    y = y.map(label_dict)

    return x, y

# Example usage:
train_path = 'train_data_final.csv'
test_path = 'test_data_final.csv'

x_train, y_train = clean_data(train_path)
x_test, y_test = clean_data(test_path)

print(x_train.head())
print(y_train.head())
print(x_test.head())
print(y_test.head())
# save as npy files
x_train = x_train.to_numpy().astype(np.float32)
y_train = y_train.to_numpy().astype(np.uint)
x_test = x_test.to_numpy().astype(np.float32)
y_test = y_test.to_numpy().astype(np.uint)

np.save('x_train.npy', x_train)
np.save('y_train.npy', y_train)
np.save('x_test.npy', x_test)
np.save('y_test.npy', y_test)
# Out:
#    rmse_mean  rmse_std  spectral_centroid_mean  spectral_centroid_std  \
# 0  -0.421358 -1.727188               -1.383174              -1.958137
# 1   0.656922  0.206084               -0.554160               0.851850
# 2  -0.884762  0.291790                0.463550               1.130857
# 3   0.850675 -0.000297               -1.346648               0.849105
# 4  -0.964743 -0.397042               -1.943950              -0.361052
#
#    spectral_bandwidth_mean  spectral_bandwidth_std  rolloff_mean  rolloff_std  \
# 0                -1.398352               -1.459741     -1.567978    -1.617502
# 1                 0.088505                1.582472     -0.328791     1.660876
# 2                 0.345553                0.288469      0.398264     0.635532
# 3                -1.016303                1.865452     -1.326038     1.611944
# 4                -2.801442                0.649098     -2.147615    -0.097324
#
#    zero_crossing_rate_mean  zero_crossing_rate_std  ...  tonnetz4_mean  \
# 0                -0.687641               -1.356702  ...      -0.243108
# 1                -0.870623               -0.567549  ...      -0.232657
# 2                 0.763398                1.164596  ...      -1.063602
# 3                -1.393551               -1.027076  ...       0.144860
# 4                -0.998820               -0.650282  ...      -1.308012
#
#    tonnetz4_std  tonnetz5_mean  tonnetz5_std  tonnetz6_mean  tonnetz6_std  \
# 0     -0.589469       1.052295     -0.663608      -0.474608     -0.370902
# 1     -0.920336      -0.464702     -1.160520      -0.508434     -0.973475
# 2      1.101448      -2.431489      0.874731       0.125493      0.907754
# 3     -1.211136      -0.107757     -1.131351      -0.152422     -1.195561
# 4      1.632290      -5.474214      2.110403      -1.745836      0.948735
#
#    chroma_cqt_mean  chroma_cqt_std  spectral_contrast_mean  \
# 0         1.104052       -1.691570               -1.414757
# 1         0.554210       -0.598164               -0.727135
# 2         0.719940       -0.237560                0.295467
# 3         0.583740       -1.174260               -0.885522
# 4        -0.609022        1.864483                1.869449
#
#    spectral_contrast_std
# 0               1.439354
# 1               0.835681
# 2               1.026858
# 3               0.180473
# 4              -2.111948
#
# [5 rows x 130 columns]
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: label, dtype: int64
#    rmse_mean  rmse_std  spectral_centroid_mean  spectral_centroid_std  \
# 0   0.551835 -0.147120                0.131044              -0.826519
# 1  -0.563390 -1.345450                1.002891              -0.742417
# 2   0.496144  0.273131                0.839827               1.205556
# 3   0.170721  0.290045                0.571022              -1.238800
# 4   0.282419  1.255941                0.575393               1.236895
#
#    spectral_bandwidth_mean  spectral_bandwidth_std  rolloff_mean  rolloff_std  \
# 0                 0.350537               -0.761074      0.303701    -0.573022
# 1                 0.572102               -1.002691      0.802243    -0.819016
# 2                 0.796600               -0.124889      0.855815    -0.245687
# 3                 0.770375               -1.347438      0.799274    -1.334666
# 4                 0.401411                0.023470      0.493990     0.546565
#
#    zero_crossing_rate_mean  zero_crossing_rate_std  ...  tonnetz4_mean  \
# 0                -0.283366               -0.517252  ...      -0.445741
# 1                 1.405591               -0.177310  ...      -1.908224
# 2                 0.678695                3.081353  ...      -0.628891
# 3                -0.234149               -0.441303  ...       0.366227
# 4                 0.262230                1.203416  ...      -1.318265
#
#    tonnetz4_std  tonnetz5_mean  tonnetz5_std  tonnetz6_mean  tonnetz6_std  \
# 0     -0.925984      -0.036017     -0.806178      -0.367353     -0.903787
# 1      0.168005      -1.919748      0.086678      -1.352068     -0.365477
# 2     -0.269723      -0.113159     -0.252264       0.034151     -0.037286
# 3     -0.834850       0.370402     -0.879218       0.410610     -0.882980
# 4      0.486951       0.090163      0.721904       0.295770      0.821250
#
#    chroma_cqt_mean  chroma_cqt_std  spectral_contrast_mean  \
# 0         0.207543       -1.419192               -0.639045
# 1        -0.800003        0.824180                0.493991
# 2        -0.981732        0.102635                0.728798
# 3         0.515753       -0.955087               -0.891738
# 4        -1.070776        0.697380                1.003570
#
#    spectral_contrast_std
# 0               0.303235
# 1              -0.253015
# 2               0.946940
# 3               0.072379
# 4              -0.312187
#
# [5 rows x 130 columns]
# 0    0
# 1    1
# 2    2
# 3    0
# 4    2
# Name: label, dtype: int64

# %%
# read npy files
x_train = np.load('x_train.npy')
print(x_train.shape)
print(x_train[0])
print(x_train.dtype)
y_train = np.load('y_train.npy')
print(y_train.shape)
print(y_train[0])
print(y_train.dtype)
# Out:
# (32000, 130)
# [-0.67169785 -1.4710041  -1.6788975  -1.8285253  -2.0823963  -1.2661979
#  -1.8117235  -1.6022962  -0.7763812  -1.345163   -0.3725419  -1.7207499
#   2.2961347  -1.3953819  -1.8297907  -1.5376248   0.5815921  -1.4731673
#  -0.05173915 -1.4999644   0.6055949  -1.5274329  -0.8847783  -1.2293793
#  -0.7630958  -1.4053953  -0.88005    -1.0974672  -0.73397076 -1.2898788
#  -0.9087216  -1.3460696  -0.49065322 -1.3329337  -0.69800794 -1.3977901
#  -0.70201427 -1.3737736  -1.1017649  -1.0943662  -0.77564496 -1.2481341
#  -0.950419   -1.4649851  -0.858817   -1.3345835  -1.0477504  -1.6132873
#  -1.3276291  -1.3775139  -1.532309   -1.4446559  -1.3301272  -0.95007473
#  -1.3632712  -1.4945269  -0.68381345 -0.76761985  0.22931328 -1.3598671
#   0.11492222 -1.0210652  -1.3722152  -1.2689304  -1.7484659  -1.3355434
#  -1.2843469  -0.88452727 -0.8303076  -1.3207625   0.07581349 -0.9651243
#   1.356685   -1.0048246   1.0659204  -0.97540593 -1.5958729  -0.8826844
#  -2.6410246  -1.1602156  -0.8873808  -1.0441631  -0.09226359 -1.1577413
#  -2.1970208  -0.9609968  -2.930356   -1.2265204  -1.212527   -1.2641169
#   1.1996168  -0.97357476  2.6340024  -1.1356617   1.1333255  -1.6862432
#   1.9911767  -0.81053513 -0.6461675  -2.024782   -1.3288342  -1.463792
#  -1.9119784  -2.6267767  -0.94506985 -1.4985603   0.49255353 -0.20239386
#  -1.1274484  -2.2507894  -0.0379536   0.238969   -0.32936364 -1.596566
#  -1.9613024  -0.6556671  -0.15092991 -0.5578001   0.2666768  -0.5599612
#   0.7599874  -0.53382725  0.5863977  -0.51450354 -0.22088137 -0.6030899
#  -0.9383421   0.9469274   1.0430648   0.65586144]
# float32
# (32000,)
# 0
# uint8
